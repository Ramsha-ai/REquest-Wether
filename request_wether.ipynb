# %%
# %%markdown
# #    **API REQuest Whether**
# #    **BY Ramsha**
# Out:
# #    **API REQuest Whether**
# #    **BY Ramsha**

# %%
import requests
url = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 25.4,
    "longitude": 68.3,
    "current": "temperature_2m"
}
response = requests.get(url, params=params)
data = response.json()
print(data)
# Out:
# {'latitude': 25.413004, 'longitude': 68.255684, 'generationtime_ms': 0.03826618194580078, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 21.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C'}, 'current': {'time': '2026-08-24T11:45', 'interval': 900, 'temperature_2m': 36.7}}
